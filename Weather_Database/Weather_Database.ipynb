# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 710

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
       # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | sitka
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | atar
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | hasaki
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 1 | fecamp
# Processing Record 17 of Set 1 | cockburn town
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | rio gallegos
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | celestun
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | saint-georges
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | hargeysa
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | nabire
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | platteville
# Processing Record 37 of Set 1 | montepuez
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | rosarito
# Processing Record 40 of Set 1 | bardiyah
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | puerto cortes
# City not found. Skipping...
# Processing Record 43 of Set 1 | sola
# Processing Record 44 of Set 1 | marrakesh
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | drayton valley
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | wuda
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | yumen
# Processing Record 4 of Set 2 | ziro
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | sinnamary
# Processing Record 7 of Set 2 | rudbar
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | mtambile
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | sistranda
# Processing Record 14 of Set 2 | quatre cocos
# Processing Record 15 of Set 2 | turayf
# Processing Record 16 of Set 2 | college
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | viking
# Processing Record 23 of Set 2 | alofi
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | mumbwa
# Processing Record 27 of Set 2 | kamenka
# Processing Record 28 of Set 2 | vila franca do campo
# Processing Record 29 of Set 2 | ternate
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | mugumu
# Processing Record 32 of Set 2 | bakhmach
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | lavrentiya
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | el cobre
# Processing Record 37 of Set 2 | buraydah
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | santa isabel do rio negro
# Processing Record 40 of Set 2 | rosetown
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | begunitsy
# Processing Record 45 of Set 2 | nara
# Processing Record 46 of Set 2 | camrose
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | saint-francois
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | manta
# Processing Record 4 of Set 3 | strezhevoy
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | black river
# Processing Record 8 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | anloga
# Processing Record 11 of Set 3 | mingyue
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | pokhara
# Processing Record 14 of Set 3 | chorbog
# City not found. Skipping...
# Processing Record 15 of Set 3 | pacasmayo
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | kloulklubed
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | cidreira
# Processing Record 21 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 3 | aras
# Processing Record 23 of Set 3 | ponta delgada
# Processing Record 24 of Set 3 | vostok
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | ribeira brava
# Processing Record 28 of Set 3 | najran
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | livingstone
# Processing Record 31 of Set 3 | oranjestad
# Processing Record 32 of Set 3 | san martin
# Processing Record 33 of Set 3 | sorland
# Processing Record 34 of Set 3 | vladicin han
# Processing Record 35 of Set 3 | saulkrasti
# Processing Record 36 of Set 3 | naze
# Processing Record 37 of Set 3 | grand gaube
# Processing Record 38 of Set 3 | lubango
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | port augusta
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 3 | vilyuysk
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | zhezkazgan
# Processing Record 49 of Set 3 | romitan
# Processing Record 50 of Set 3 | ishigaki
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | trairi
# Processing Record 3 of Set 4 | howard springs
# Processing Record 4 of Set 4 | salekhard
# Processing Record 5 of Set 4 | rockport
# Processing Record 6 of Set 4 | dronfield
# Processing Record 7 of Set 4 | businga
# Processing Record 8 of Set 4 | ketchikan
# Processing Record 9 of Set 4 | am timan
# Processing Record 10 of Set 4 | mangrol
# Processing Record 11 of Set 4 | jaisalmer
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | pangnirtung
# Processing Record 14 of Set 4 | taltal
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | dunedin
# Processing Record 17 of Set 4 | waingapu
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | honiara
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | paita
# Processing Record 25 of Set 4 | omsukchan
# Processing Record 26 of Set 4 | manggar
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | namatanai
# Processing Record 29 of Set 4 | bada
# Processing Record 30 of Set 4 | alugan
# Processing Record 31 of Set 4 | grand-santi
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | songjianghe
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | egvekinot
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | tateyama
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | gimli
# Processing Record 42 of Set 4 | wahiawa
# Processing Record 43 of Set 4 | nome
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | sovetskiy
# Processing Record 47 of Set 4 | roma
# Processing Record 48 of Set 4 | havre-saint-pierre
# Processing Record 49 of Set 4 | merauke
# Processing Record 50 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 5 | benghazi
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | vilhena
# Processing Record 4 of Set 5 | loudi
# Processing Record 5 of Set 5 | flinders
# Processing Record 6 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | sur
# Processing Record 9 of Set 5 | lisakovsk
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | soyo
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | at-bashi
# Processing Record 14 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 5 | labuhan
# Processing Record 16 of Set 5 | portsoy
# Processing Record 17 of Set 5 | ipira
# Processing Record 18 of Set 5 | barrow
# Processing Record 19 of Set 5 | karasuk
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | milford
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | boundiali
# Processing Record 24 of Set 5 | kahului
# Processing Record 25 of Set 5 | imbituba
# Processing Record 26 of Set 5 | hoa binh
# Processing Record 27 of Set 5 | altay
# Processing Record 28 of Set 5 | silleda
# Processing Record 29 of Set 5 | chara
# Processing Record 30 of Set 5 | buluang
# Processing Record 31 of Set 5 | paldiski
# Processing Record 32 of Set 5 | sabha
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | marsh harbour
# Processing Record 35 of Set 5 | zhigansk
# Processing Record 36 of Set 5 | berlevag
# Processing Record 37 of Set 5 | manokwari
# Processing Record 38 of Set 5 | seoul
# Processing Record 39 of Set 5 | cerrito
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | takoradi
# Processing Record 42 of Set 5 | pingyi
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 45 of Set 5 | guilin
# Processing Record 46 of Set 5 | puerto escondido
# Processing Record 47 of Set 5 | chumikan
# Processing Record 48 of Set 5 | krasnoselkup
# Processing Record 49 of Set 5 | losevo
# Processing Record 50 of Set 5 | besenyotelek
# Processing Record 1 of Set 6 | elliot
# Processing Record 2 of Set 6 | saint anthony
# Processing Record 3 of Set 6 | opuwo
# Processing Record 4 of Set 6 | trincomalee
# Processing Record 5 of Set 6 | kavaratti
# Processing Record 6 of Set 6 | richards bay
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | parrita
# Processing Record 10 of Set 6 | venice
# Processing Record 11 of Set 6 | miguel hidalgo
# Processing Record 12 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 6 | burnie
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | kanigiri
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | abha
# Processing Record 19 of Set 6 | bredasdorp
# Processing Record 20 of Set 6 | irtyshskiy
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 6 | nesebar
# Processing Record 23 of Set 6 | costinesti
# Processing Record 24 of Set 6 | ulladulla
# Processing Record 25 of Set 6 | dickinson
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | kandrian
# Processing Record 29 of Set 6 | san andres
# Processing Record 30 of Set 6 | chhatak
# Processing Record 31 of Set 6 | svencionys
# Processing Record 32 of Set 6 | terrace bay
# Processing Record 33 of Set 6 | nouakchott
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | tambo
# Processing Record 36 of Set 6 | ixtapa
# Processing Record 37 of Set 6 | siva
# Processing Record 38 of Set 6 | tucurui
# Processing Record 39 of Set 6 | zachary
# Processing Record 40 of Set 6 | langsa
# Processing Record 41 of Set 6 | trelew
# Processing Record 42 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 6 | sakakah
# Processing Record 44 of Set 6 | caucaia
# Processing Record 45 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 46 of Set 6 | ceres
# Processing Record 47 of Set 6 | eyl
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | verkhnyaya toyma
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | shache
# Processing Record 2 of Set 7 | ridgecrest
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | upernavik
# Processing Record 5 of Set 7 | carballo
# Processing Record 6 of Set 7 | esperance
# Processing Record 7 of Set 7 | russell
# Processing Record 8 of Set 7 | owosso
# Processing Record 9 of Set 7 | muli
# Processing Record 10 of Set 7 | yerbogachen
# Processing Record 11 of Set 7 | darhan
# Processing Record 12 of Set 7 | ust-koksa
# Processing Record 13 of Set 7 | verkhnyaya inta
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | ambanja
# Processing Record 17 of Set 7 | siderno
# Processing Record 18 of Set 7 | makarska
# Processing Record 19 of Set 7 | rapid valley
# Processing Record 20 of Set 7 | kruisfontein
# Processing Record 21 of Set 7 | camana
# Processing Record 22 of Set 7 | kununurra
# Processing Record 23 of Set 7 | caninde
# Processing Record 24 of Set 7 | iberia
# Processing Record 25 of Set 7 | paamiut
# Processing Record 26 of Set 7 | palmer
# Processing Record 27 of Set 7 | kaduqli
# Processing Record 28 of Set 7 | sal rei
# Processing Record 29 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 7 | genhe
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | san diego
# Processing Record 33 of Set 7 | avera
# Processing Record 34 of Set 7 | biltine
# Processing Record 35 of Set 7 | khilok
# Processing Record 36 of Set 7 | grindavik
# Processing Record 37 of Set 7 | novobirilyussy
# Processing Record 38 of Set 7 | harij
# Processing Record 39 of Set 7 | yaan
# Processing Record 40 of Set 7 | jiayuguan
# Processing Record 41 of Set 7 | tanout
# Processing Record 42 of Set 7 | sao gabriel da cachoeira
# Processing Record 43 of Set 7 | petrolandia
# City not found. Skipping...
# Processing Record 44 of Set 7 | pangoa
# Processing Record 45 of Set 7 | redmond
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | gondanglegi
# Processing Record 48 of Set 7 | nagato
# Processing Record 49 of Set 7 | vyartsilya
# Processing Record 50 of Set 7 | husavik
# Processing Record 1 of Set 8 | burley
# Processing Record 2 of Set 8 | alyangula
# Processing Record 3 of Set 8 | kamen-rybolov
# Processing Record 4 of Set 8 | malartic
# Processing Record 5 of Set 8 | natal
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | mayo
# Processing Record 8 of Set 8 | itarema
# Processing Record 9 of Set 8 | rockland
# Processing Record 10 of Set 8 | nanortalik
# Processing Record 11 of Set 8 | dordrecht
# Processing Record 12 of Set 8 | fethiye
# Processing Record 13 of Set 8 | atlantic city
# Processing Record 14 of Set 8 | chiredzi
# Processing Record 15 of Set 8 | maniitsoq
# Processing Record 16 of Set 8 | qeshm
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | batasan
# Processing Record 19 of Set 8 | salinas
# Processing Record 20 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 8 | san jeronimo
# Processing Record 22 of Set 8 | sisimiut
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | inuvik
# Processing Record 25 of Set 8 | belaya gora
# Processing Record 26 of Set 8 | bilma
# Processing Record 27 of Set 8 | muravlenko
# Processing Record 28 of Set 8 | zile
# Processing Record 29 of Set 8 | christchurch
# Processing Record 30 of Set 8 | halifax
# Processing Record 31 of Set 8 | sorong
# Processing Record 32 of Set 8 | tura
# Processing Record 33 of Set 8 | likasi
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | hefei
# Processing Record 36 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 8 | kaeo
# Processing Record 38 of Set 8 | kaura namoda
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 41 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 8 | kaniama
# Processing Record 43 of Set 8 | matara
# Processing Record 44 of Set 8 | asau
# Processing Record 45 of Set 8 | mizdah
# Processing Record 46 of Set 8 | itaituba
# Processing Record 47 of Set 8 | berdigestyakh
# Processing Record 48 of Set 8 | novouzensk
# Processing Record 49 of Set 8 | takhtamygda
# Processing Record 50 of Set 8 | bundaberg
# Processing Record 1 of Set 9 | meiganga
# Processing Record 2 of Set 9 | monte patria
# Processing Record 3 of Set 9 | campos
# Processing Record 4 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | noshiro
# Processing Record 7 of Set 9 | clyde river
# Processing Record 8 of Set 9 | mantua
# Processing Record 9 of Set 9 | ouadda
# Processing Record 10 of Set 9 | la ronge
# Processing Record 11 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 9 | andenes
# Processing Record 13 of Set 9 | wanning
# Processing Record 14 of Set 9 | chakulia
# Processing Record 15 of Set 9 | djougou
# Processing Record 16 of Set 9 | palmerston
# Processing Record 17 of Set 9 | przhevalskoye
# Processing Record 18 of Set 9 | atkinson
# Processing Record 19 of Set 9 | pashiya
# Processing Record 20 of Set 9 | saint-pierre
# Processing Record 21 of Set 9 | nizhniy odes
# Processing Record 22 of Set 9 | riohacha
# Processing Record 23 of Set 9 | khasan
# Processing Record 24 of Set 9 | agva
# City not found. Skipping...
# Processing Record 25 of Set 9 | te anau
# Processing Record 26 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 9 | benguela
# Processing Record 28 of Set 9 | raudeberg
# Processing Record 29 of Set 9 | bubaque
# Processing Record 30 of Set 9 | parli
# Processing Record 31 of Set 9 | mezen
# Processing Record 32 of Set 9 | ilula
# Processing Record 33 of Set 9 | panguna
# Processing Record 34 of Set 9 | great yarmouth
# Processing Record 35 of Set 9 | walvis bay
# Processing Record 36 of Set 9 | aripuana
# Processing Record 37 of Set 9 | besikduzu
# Processing Record 38 of Set 9 | bhinmal
# Processing Record 39 of Set 9 | kariba
# Processing Record 40 of Set 9 | sapele
# Processing Record 41 of Set 9 | pimenta bueno
# Processing Record 42 of Set 9 | viedma
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | paraiso
# Processing Record 45 of Set 9 | maun
# Processing Record 46 of Set 9 | ofaqim
# Processing Record 47 of Set 9 | ambulu
# Processing Record 48 of Set 9 | yamada
# Processing Record 49 of Set 9 | heerenveen
# Processing Record 50 of Set 9 | vao
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | sijunjung
# Processing Record 3 of Set 10 | otjimbingwe
# Processing Record 4 of Set 10 | vagur
# Processing Record 5 of Set 10 | the valley
# Processing Record 6 of Set 10 | narsaq
# Processing Record 7 of Set 10 | severo-kurilsk
# Processing Record 8 of Set 10 | alpena
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | yulara
# Processing Record 11 of Set 10 | great falls
# Processing Record 12 of Set 10 | skjervoy
# Processing Record 13 of Set 10 | biscarrosse
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | fort nelson
# Processing Record 16 of Set 10 | banska bystrica
# Processing Record 17 of Set 10 | filadelfia
# Processing Record 18 of Set 10 | evensk
# Processing Record 19 of Set 10 | moree
# Processing Record 20 of Set 10 | brokopondo
# Processing Record 21 of Set 10 | usva
# City not found. Skipping...
# Processing Record 22 of Set 10 | fuerte olimpo
# Processing Record 23 of Set 10 | koygorodok
# Processing Record 24 of Set 10 | birjand
# Processing Record 25 of Set 10 | cedar city
# Processing Record 26 of Set 10 | wilmington
# Processing Record 27 of Set 10 | lazaro cardenas
# Processing Record 28 of Set 10 | sao felix do xingu
# Processing Record 29 of Set 10 | brae
# Processing Record 30 of Set 10 | port-gentil
# Processing Record 31 of Set 10 | mount lebanon
# Processing Record 32 of Set 10 | mount gambier
# Processing Record 33 of Set 10 | iqaluit
# Processing Record 34 of Set 10 | ngorongoro
# Processing Record 35 of Set 10 | adrar
# Processing Record 36 of Set 10 | qui nhon
# Processing Record 37 of Set 10 | lata
# Processing Record 38 of Set 10 | milkovo
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | dandong
# Processing Record 41 of Set 10 | beyneu
# Processing Record 42 of Set 10 | khorramshahr
# Processing Record 43 of Set 10 | takab
# Processing Record 44 of Set 10 | surt
# Processing Record 45 of Set 10 | shenjiamen
# Processing Record 46 of Set 10 | dongsheng
# Processing Record 47 of Set 10 | salalah
# Processing Record 48 of Set 10 | iralaya
# Processing Record 49 of Set 10 | noumea
# Processing Record 50 of Set 10 | cayenne
# Processing Record 1 of Set 11 | okhotsk
# Processing Record 2 of Set 11 | cumbitara
# Processing Record 3 of Set 11 | presidencia roque saenz pena
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | lamu
# Processing Record 6 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao joao da barra
# Processing Record 8 of Set 11 | partenit
# Processing Record 9 of Set 11 | kelso
# Processing Record 10 of Set 11 | mitsamiouli
# Processing Record 11 of Set 11 | biak
# Processing Record 12 of Set 11 | antofagasta
# Processing Record 13 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 11 | portgordon
# Processing Record 15 of Set 11 | moussoro
# Processing Record 16 of Set 11 | port moresby
# Processing Record 17 of Set 11 | roebourne
# Processing Record 18 of Set 11 | liverpool
# Processing Record 19 of Set 11 | hami
# Processing Record 20 of Set 11 | kagadi
# Processing Record 21 of Set 11 | dombarovskiy
# Processing Record 22 of Set 11 | cestas
# Processing Record 23 of Set 11 | porto novo
# Processing Record 24 of Set 11 | kankan
# Processing Record 25 of Set 11 | north bend
# Processing Record 26 of Set 11 | tigil
# Processing Record 27 of Set 11 | praia
# Processing Record 28 of Set 11 | ust-tsilma
# Processing Record 29 of Set 11 | zhongshu
# Processing Record 30 of Set 11 | banda aceh
# Processing Record 31 of Set 11 | kashmor
# Processing Record 32 of Set 11 | traverse city
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | takestan
# Processing Record 35 of Set 11 | dumka
# Processing Record 36 of Set 11 | gigmoto
# Processing Record 37 of Set 11 | aplahoue
# Processing Record 38 of Set 11 | myaundzha
# Processing Record 39 of Set 11 | kargasok
# Processing Record 40 of Set 11 | high rock
# Processing Record 41 of Set 11 | channel-port aux basques
# Processing Record 42 of Set 11 | hay river
# Processing Record 43 of Set 11 | dingle
# Processing Record 44 of Set 11 | kenai
# Processing Record 45 of Set 11 | morondava
# Processing Record 46 of Set 11 | leshukonskoye
# Processing Record 47 of Set 11 | ormara
# Processing Record 48 of Set 11 | tabas
# Processing Record 49 of Set 11 | semypolky
# Processing Record 50 of Set 11 | port keats
# Processing Record 1 of Set 12 | san cristobal
# Processing Record 2 of Set 12 | tamandare
# Processing Record 3 of Set 12 | hailar
# Processing Record 4 of Set 12 | port hedland
# Processing Record 5 of Set 12 | batesville
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | pochutla
# Processing Record 8 of Set 12 | coquimbo
# Processing Record 9 of Set 12 | hurghada
# Processing Record 10 of Set 12 | ikeda
# Processing Record 11 of Set 12 | bathsheba
# Processing Record 12 of Set 12 | chicama
# Processing Record 13 of Set 12 | camacha
# Processing Record 14 of Set 12 | bako
# Processing Record 15 of Set 12 | saquena
# Processing Record 16 of Set 12 | shatalovo
# Processing Record 17 of Set 12 | san lawrenz
# Processing Record 18 of Set 12 | victor harbor
# Processing Record 19 of Set 12 | ahuimanu
# Processing Record 20 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 21 of Set 12 | broken hill
# Processing Record 22 of Set 12 | khandyga
# Processing Record 23 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 12 | eenhana
# Processing Record 25 of Set 12 | yeppoon
# Processing Record 26 of Set 12 | teahupoo
# Processing Record 27 of Set 12 | ferrol
# Processing Record 28 of Set 12 | luang prabang
# Processing Record 29 of Set 12 | solnechnyy
# Processing Record 30 of Set 12 | santa rosa
# Processing Record 31 of Set 12 | hualmay
# Processing Record 32 of Set 12 | bowen
# Processing Record 33 of Set 12 | sigayevo
# Processing Record 34 of Set 12 | poum
# Processing Record 35 of Set 12 | ngunguru
# Processing Record 36 of Set 12 | khandbari
# Processing Record 37 of Set 12 | shirvan
# Processing Record 38 of Set 12 | sechura
# Processing Record 39 of Set 12 | uaua
# Processing Record 40 of Set 12 | scharding
# Processing Record 41 of Set 12 | stornoway
# Processing Record 42 of Set 12 | el real de santa maria
# Processing Record 43 of Set 12 | mango
# Processing Record 44 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 12 | alta floresta
# Processing Record 46 of Set 12 | sembakung
# Processing Record 47 of Set 12 | mineiros
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | demba
# Processing Record 50 of Set 12 | bosaso
# Processing Record 1 of Set 13 | porto nacional
# Processing Record 2 of Set 13 | omboue
# Processing Record 3 of Set 13 | paka
# Processing Record 4 of Set 13 | olafsvik
# Processing Record 5 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | lorengau
# Processing Record 7 of Set 13 | hervey bay
# Processing Record 8 of Set 13 | nelson
# Processing Record 9 of Set 13 | ranong
# Processing Record 10 of Set 13 | picton
# Processing Record 11 of Set 13 | portalegre
# Processing Record 12 of Set 13 | saint-augustin
# Processing Record 13 of Set 13 | ugoofaaru
# Processing Record 14 of Set 13 | praia da vitoria
# Processing Record 15 of Set 13 | akdepe
# Processing Record 16 of Set 13 | troitsko-pechorsk
# Processing Record 17 of Set 13 | concepcion del uruguay
# Processing Record 18 of Set 13 | flin flon
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | snyder
# Processing Record 21 of Set 13 | mancio lima
# Processing Record 22 of Set 13 | winneba
# Processing Record 23 of Set 13 | yayva
# Processing Record 24 of Set 13 | namie
# Processing Record 25 of Set 13 | sumbe
# Processing Record 26 of Set 13 | simpang
# Processing Record 27 of Set 13 | kormilovka
# Processing Record 28 of Set 13 | magadan
# Processing Record 29 of Set 13 | welkom
# Processing Record 30 of Set 13 | mandera
# Processing Record 31 of Set 13 | bud
# Processing Record 32 of Set 13 | porto velho
# Processing Record 33 of Set 13 | bulawayo
# Processing Record 34 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 13 | valdivia
# Processing Record 36 of Set 13 | tamiahua
# Processing Record 37 of Set 13 | beringovskiy
# Processing Record 38 of Set 13 | bijie
# Processing Record 39 of Set 13 | alamor
# Processing Record 40 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 41 of Set 13 | maroantsetra
# Processing Record 42 of Set 13 | jesus carranza
# Processing Record 43 of Set 13 | mwinilunga
# Processing Record 44 of Set 13 | muisne
# Processing Record 45 of Set 13 | leh
# Processing Record 46 of Set 13 | sisak
# Processing Record 47 of Set 13 | marsa matruh
# Processing Record 48 of Set 13 | port hardy
# Processing Record 49 of Set 13 | karasjok
# Processing Record 50 of Set 13 | valparaiso
# Processing Record 1 of Set 14 | ibra
# Processing Record 2 of Set 14 | borazjan
# Processing Record 3 of Set 14 | porbandar
# Processing Record 4 of Set 14 | vila
# Processing Record 5 of Set 14 | havelock
# Processing Record 6 of Set 14 | tautira
# Processing Record 7 of Set 14 | barwaha
# City not found. Skipping...
# Processing Record 8 of Set 14 | durango
# Processing Record 9 of Set 14 | zlin
# Processing Record 10 of Set 14 | lovington
# Processing Record 11 of Set 14 | xining
# Processing Record 12 of Set 14 | dayton
# Processing Record 13 of Set 14 | imeni poliny osipenko
# Processing Record 14 of Set 14 | fort-shevchenko
# Processing Record 15 of Set 14 | norden
# Processing Record 16 of Set 14 | szigetvar
# Processing Record 17 of Set 14 | cap malheureux
# Processing Record 18 of Set 14 | hambantota
# Processing Record 19 of Set 14 | teguldet
# Processing Record 20 of Set 14 | sao paulo de olivenca
# Processing Record 21 of Set 14 | svetlogorsk
# Processing Record 22 of Set 14 | haapiti
# Processing Record 23 of Set 14 | komsomolskiy
# Processing Record 24 of Set 14 | spasskoye
# Processing Record 25 of Set 14 | puerto madero
# Processing Record 26 of Set 14 | vestmannaeyjar
# Processing Record 27 of Set 14 | sirajganj
# Processing Record 28 of Set 14 | novikovo
# Processing Record 29 of Set 14 | badaojiang
# City not found. Skipping...
# Processing Record 30 of Set 14 | saratoga springs
# Processing Record 31 of Set 14 | north myrtle beach
# Processing Record 32 of Set 14 | kholm-zhirkovskiy
# Processing Record 33 of Set 14 | comodoro rivadavia
# Processing Record 34 of Set 14 | nyurba
# Processing Record 35 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 14 | wau
# Processing Record 37 of Set 14 | miraflores
# Processing Record 38 of Set 14 | preobrazheniye
# Processing Record 39 of Set 14 | lira
# Processing Record 40 of Set 14 | prieska
# Processing Record 41 of Set 14 | tocopilla
# Processing Record 42 of Set 14 | half moon bay
# Processing Record 43 of Set 14 | dali
# Processing Record 44 of Set 14 | bagotville
# Processing Record 45 of Set 14 | tadine
# Processing Record 46 of Set 14 | turinskaya sloboda
# Processing Record 47 of Set 14 | narathiwat
# Processing Record 48 of Set 14 | ulaangom
# Processing Record 49 of Set 14 | auki
# Processing Record 50 of Set 14 | maryville
# Processing Record 1 of Set 15 | mayumba
# Processing Record 2 of Set 15 | kumluca
# Processing Record 3 of Set 15 | la rioja
# Processing Record 4 of Set 15 | bojnurd
# Processing Record 5 of Set 15 | srandakan
# Processing Record 6 of Set 15 | hvide sande
# Processing Record 7 of Set 15 | carutapera
# Processing Record 8 of Set 15 | chapais
# Processing Record 9 of Set 15 | price
# Processing Record 10 of Set 15 | qingan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua      CK -21.2078 -159.7750     71.65        78          20
# 1       Tasiilaq      GL  65.6145  -37.6368     39.36        96         100
# 2          Sitka      US  57.0531 -135.3300     48.09        76          90
# 3        Qaanaaq      GL  77.4840  -69.3632     32.50        93          38
# 4         Atuona      PF  -9.8000 -139.0333     78.51        71          13
# ..           ...     ...      ...       ...       ...       ...         ...
# 654    Srandakan      ID  -7.9386  110.2506     59.74        88         100
# 655  Hvide Sande      DK  56.0045    8.1294     70.38        83          17
# 656   Carutapera      BR  -1.1950  -46.0200     86.23        64          99
# 657      Chapais      CA  49.7834  -74.8492     46.18        31           3
# 658        Price      US  39.5994 -110.8107     72.66        20           1
#
#      Wind Speed Current Description
# 0          3.44          few clouds
# 1         14.83          light rain
# 2         11.50          light rain
# 3          6.04    scattered clouds
# 4         10.94          few clouds
# ..          ...                 ...
# 654        3.13     overcast clouds
# 655        8.99          few clouds
# 656        8.61     overcast clouds
# 657        5.41           clear sky
# 658        8.05           clear sky
#
# [659 rows x 9 columns]
